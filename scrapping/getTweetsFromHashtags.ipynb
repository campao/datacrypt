# %%
import tweepy
import csv
import pandas as pd

class getTweetsFromHashtags:
    def __init__(self):
        self.hashtags = ["btc", "bitcoin", "cryptocurrency", "crypto"]
        self.consumer_key = 'yukvJ57xhaswhsXgWPRw4cByU'
        self.consumer_secret = 'cAF5ZI0QJbaVvTcFsrvWnb6QLqNl5AS6hxxMd2JlMk7dbRBrT9'
        self.access_token = '734812424566648834-qLfG7N5Yx0fWjGFLsCjFzxXTk9IKAjp'
        self.access_token_secret = '5lHhqIMTBEHLVhRlnjUp4WaylTH5vb70A11WR86Gw9XMh'
        try: 
            # OAuthHandler object 
            auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
        except tweepy.TweepError as e:
            print(f"Error: Twitter Authentication Failed - \n{str(e)}") 
    
    def getTweetsFromLastHour(self):
        tweets = [] 
        sinceId = None
        max_id = -1
        tweetCount = 0
        tweetsPerQry = 100
        until = '2014-09-18 18:44:00'
        while tweetCount < maxTweets:
            

getTw = getTweetsFromHashtags()
getTw.getTweetsFromLastHour()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-38b2486758fc> in <module>
#      27
#      28 getTw = getTweetsFromHashtags()
# ---> 29 getTw.getTweetsFromLastHour()
#
# <ipython-input-39-38b2486758fc> in getTweetsFromLastHour(self)
#      22         until = '2014-09-18 18:44:00'
#      23         tweetLists = tweepy.Cursor(api.search,q="BTC", lang="en").items(99999)
# ---> 24         for elem in tweetLists:
#      25             print("toto")
#      26             print(elem.created_at)
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     160                                     if self.wait_on_rate_limit_notify:
#     161                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 162                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     163
#     164                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
import pandas as pd
import tweepy
from tweepy import OAuthHandler


class TwitterClient(object): 
    def __init__(self):
        # Access Credentials 
        consumer_key = 'yukvJ57xhaswhsXgWPRw4cByU'
        consumer_secret = 'cAF5ZI0QJbaVvTcFsrvWnb6QLqNl5AS6hxxMd2JlMk7dbRBrT9'
        access_token = '734812424566648834-qLfG7N5Yx0fWjGFLsCjFzxXTk9IKAjp'
        access_token_secret = '5lHhqIMTBEHLVhRlnjUp4WaylTH5vb70A11WR86Gw9XMh'
        
        try: 
            # OAuthHandler object 
            auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
            
        except tweepy.TweepError as e:
            print(f"Error: Twitter Authentication Failed - \n{str(e)}") 

    # Function to fetch tweets
    def get_tweets_from_hashtag(self, query, maxTweets = 200): 
        # empty list to store parsed tweets 
        tweets = [] 
        sinceId = None
        max_id = -1
        tweetCount = 0
        tweetsPerQry = 200
        
        while tweetCount < maxTweets:
            try:
                if (max_id <= 0):
                    if (not sinceId):
                        new_tweets = self.api.search(q=query, count=tweetsPerQry, lang='en', result_type='popular')
                    else:
                        new_tweets = self.api.search(q=query, count=tweetsPerQry,
                                                since_id=sinceId, lang='en', result_type='popular')
                else:
                    if (not sinceId):
                        new_tweets = self.api.search(q=query, count=tweetsPerQry,
                                                max_id=str(max_id - 1), lang='en', result_type='popular')
                    else:
                        new_tweets = self.api.search(q=query, count=tweetsPerQry,
                                                max_id=str(max_id - 1),
                                                since_id=sinceId, lang='en', result_type='popular')
                if not new_tweets:
                    print("No more tweets found")
                    break
                    
                for tweet in new_tweets:
                    parsed_tweet = {} 
                    parsed_tweet['id'] = tweet.id
                    parsed_tweet['created_at'] = tweet.created_at
                    parsed_tweet['tweets'] = tweet.text
                    parsed_tweet['retweet_count'] = tweet.retweet_count
                    parsed_tweet['favorite_count'] = tweet.favorite_count
                    parsed_tweet['followers_count'] = tweet.user.followers_count
                    # appending parsed tweet to tweets list 
                    if tweet.retweet_count > 0: 
                        # if tweet has retweets, ensure that it is appended only once 
                        if parsed_tweet not in tweets: 
                            tweets.append(parsed_tweet) 
                    else: 
                        tweets.append(parsed_tweet) 
                        
                tweetCount += len(new_tweets)
                print("Downloaded {0} tweets".format(tweetCount))
                max_id = new_tweets[-1].id

            except tweepy.TweepError as e:
                print("Tweepy error : " + str(e))
                break
        print(tweets)
        pd.DataFrame(tweets).to_csv("{}___{}__{}.csv".format(query[1:-1], tweets[0]["created_at"], tweets[len(tweets) - 1]['created_at']))
        return pd.DataFrame(tweets)
    
    def get_tweets_from_person(self, user_id):
        tweets = []
        tweetsPerQuerry = 200
        new_tweets = []
        oldest=-1
        
        print('user_id ' + user_id)
        new_tweets = self.api.user_timeline(id=user_id,
                                                count=200)
        for tweet in new_tweets:
            parsed_tweet = {}
            parsed_tweet['id'] = tweet.id
            parsed_tweet['created_at'] = tweet.created_at
            parsed_tweet['tweets'] = tweet.text
            parsed_tweet['retweet_count'] = tweet.retweet_count
            parsed_tweet['favorite_count'] = tweet.favorite_count
            parsed_tweet['followers_count'] = tweet.user.followers_count
            tweets.append(parsed_tweet)
        oldest = tweets[- 1]['id'] - 1
        while len(new_tweets) > 0 or tweets == []:
            new_tweets = self.api.user_timeline(id=user_id,
                                                count=200,
                                                max_id=oldest)
            for tweet in new_tweets:
                parsed_tweet = {} 
                parsed_tweet['id'] = tweet.id
                parsed_tweet['created_at'] = tweet.created_at
                parsed_tweet['tweets'] = tweet.text
                parsed_tweet['retweet_count'] = tweet.retweet_count
                parsed_tweet['favorite_count'] = tweet.favorite_count
                parsed_tweet['followers_count'] = tweet.user.followers_count
                tweets.append(parsed_tweet) 
            if (len(tweets) != 0):
                oldest = tweets[-1]['id'] - 1
        #print(tweets)
        #pd.DataFrame(tweets).to_csv("{}.csv".format(user_id))
        return tweets                       
    
    def parse_users(self):
        df_users = pd.read_csv("data/twitter_users.csv", sep=';')
        
        
        for rows in df_users['user_id']:
            tweets = self.get_tweets_from_person(rows)
            pd.DataFrame(tweets).to_csv("data/user/{}___{}__{}.csv".format(rows[1:], tweets[0]['created_at'], tweets[-1]['created_at']))
twiCli = TwitterClient()
#ret = twiCli.get_tweets_from_hashtag('"bitcoin"')
ret = twiCli.parse_users()
# Out:
# user_id @VitalikButerin
# user_id @rogerkver
# user_id @brockpierce
# user_id @SatoshiLite
# user_id @officialmcafee
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-c9ae6575af2f> in <module>
#     124 twiCli = TwitterClient()
#     125 #ret = twiCli.get_tweets_from_hashtag('"bitcoin"')
# --> 126 ret = twiCli.parse_users()
#
# <ipython-input-87-c9ae6575af2f> in parse_users(self)
#     120
#     121         for rows in df_users['user_id']:
# --> 122             tweets = self.get_tweets_from_person(rows)
#     123             pd.DataFrame(tweets).to_csv("data/user/{}___{}__{}.csv".format(rows[1:], tweets[0]['created_at'], tweets[-1]['created_at']))
#     124 twiCli = TwitterClient()
#
# <ipython-input-87-c9ae6575af2f> in get_tweets_from_person(self, user_id)
#     100                                                 count=200,
#     101                                                 max_id=oldest)
# --> 102             for tweet in new_tweets:
#     103                 parsed_tweet = {}
#     104                 parsed_tweet['id'] = tweet.id
#
# KeyboardInterrupt:
